# %% [markdown]
# Array is a container of values of the same type
#
# syntax:
#     var=array(type code, [elements])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from array import *

# %%
arr=array('H',[-1,2,3,4,5])
arr
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 arr=array('H',[-1,2,3,4,5])
#       2 arr
#
# OverflowError: unsigned short is less than minimum

# %%
arr=array('i',[1,2,3,4,5])
arr
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
arr.buffer_info()
# Out:
# (2498318710384, 5)

# %%
arr[2]
# Out:
# 3

# %%
for i in arr:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for pnt in range(5):
    print(pnt ,arr[pnt])
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
arr.reverse()
arr
# Out:
# array('i', [5, 4, 3, 2, 1])

# %%
arr.append(10)
arr
# Out:
# array('i', [5, 4, 3, 2, 1, 10, 10])

# %%
arr.remove(2)
# if there are 2 or more elements of same value the first element gets removed
arr
# Out:
# array('i', [5, 4, 3, 1, 10, 10])

# %%
arr.index(5)
# returns the position of an array element
# Out:
# 0

# %%
x=int(input('Enter an array size'))
arr1=[]
for i in range(x):
    n=int(input('Enter values'))
    arr1.append(n)
print(arr1)
# Out:
# Enter an array size2
# Enter values1
# Enter values2
# [1, 2]
