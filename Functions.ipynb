# %% [markdown]
# Function is a set of code that performs some task
#
#     def function_name:
#         statements

# %%
def welcome():
    print('Hello world')
welcome()
# Out:
# Hello world

# %%
# pass by reference
def add(x,y):
    print(id(x),id(y))
    z=x+y
    return z
x=2
y=3
add(x,y)
print(id(x),id(y))
# Out:
# 2513446201680 2513446201712
# 2513446201680 2513446201712

# %%
def add(x=0,y=0):
    z=x+y
    return z
add()
# Out:
# 0

# %%
def add(*a):
    sum=0
    for i in a:
        sum+=i
    print('The sum is', sum)
add(10,20)
# Out:
# The sum is 30

# %% [markdown]
# ![image.png](attachment:image.png)
